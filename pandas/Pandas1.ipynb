# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
data = [343 , 344, 3454.4, 564, 343]

# %%
series = pd.Series(data, index = ['a' , "barbie" , 'c' , 'd', 'e'])

# %%
print(series)
# Out:
# a          343.0
# barbie     344.0
# c         3454.4
# d          564.0
# e          343.0
# dtype: float64

# %%
print(series.loc['c'])
# Out:
# 3454.4

# %%
series.loc['c'] = 111.02

# %%
print(series.loc['c'])
# Out:
# 111.02

# %%
print(series.iloc[3])
# Out:
# 564.0

# %%
print(series[series > 554]+ 434)
# Out:
# d    998.0
# dtype: float64

# %%
diet = {
    "day1" : 420,
    "day2" : 380,
    "day3" : 390
}

# %%
series = pd.Series(diet)

# %%
print(series)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
print(series.loc["day1"])
# Out:
# 420

# %%
print(series[series >= 299])
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
#Data Frame

# %%
character = {
    "Name" : ["Rudra", "Pawan" , "Rashmi"],
    "Age" : [39, 44, 23]
}

# %%
df = pd.DataFrame(character, index = ["Stud 1", "Stud 2", "Stud 3"])

# %%
print(df)
# Out:
#           Name  Age
# Stud 1   Rudra   39
# Stud 2   Pawan   44
# Stud 3  Rashmi   23

# %%
print(df.loc["Stud 1"])
# Out:
# Name    Rudra
# Age        39
# Name: Stud 1, dtype: object

# %%
print(df.iloc[2])
# Out:
# Name    Rashmi
# Age         23
# Name: Stud 3, dtype: object

# %%
# Add a new column

# %%
df["Job"] = ["Engineer" , "Doctor" , "Teacher"]

# %%
print(df)
# Out:
#           Name  Age       Job
# Stud 1   Rudra   39  Engineer
# Stud 2   Pawan   44    Doctor
# Stud 3  Rashmi   23   Teacher

# %%
# Add a new row

# %%
new_row = pd.DataFrame([{"Name": "Sandepp","Age" : 34, "Job" : "Creminal"}],
                       index = ["Stud 4"])

# %%
df = pd.concat([df,new_row])

# %%
print(df)
# Out:
#            Name  Age       Job
# Stud 1    Rudra   39  Engineer
# Stud 2    Pawan   44    Doctor
# Stud 3   Rashmi   23   Teacher
# 0       Sandepp   34  Creminal
# Stud 4  Sandepp   34  Creminal
# Stud 4  Sandepp   34  Creminal

# %%
add_row = pd.DataFrame([{"Name": "Sandepp","Age" : 34, "Job" : "Creminal"},
                        {"Name": "Hagga","Age" : 34, "Job" : "Creminal"}],
                       index = ["Stud 6" ,"Stud 7"])

# %%
df = pd.concat([df,add_row])

# %%
print(df)
# Out:
#            Name  Age       Job
# Stud 1    Rudra   39  Engineer
# Stud 2    Pawan   44    Doctor
# Stud 3   Rashmi   23   Teacher
# 0       Sandepp   34  Creminal
# Stud 4  Sandepp   34  Creminal
# Stud 4  Sandepp   34  Creminal
# Stud 6  Sandepp   34  Creminal
# Stud 7    Hagga   34  Creminal

# %%
df.to_csv('students.csv', index=True)

# %%
df = pd.read_csv("new.csv", index_col = "Name")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-60514ad6-b39b-4ae0-8724-b25d8559bba5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60514ad6-b39b-4ae0-8724-b25d8559bba5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
print(df.to_string())
# Out:
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass    Poison     0.7     6.9          0
# 1      2     Ivysaur     Grass    Poison     1.0    13.0          0
# 2      3    Venusaur     Grass    Poison     2.0   100.0          0
# 3      4  Charmander      Fire       NaN     0.6     8.5          0
# 4      5  Charmeleon      Fire       NaN     1.1    19.0          0
# 5      6   Charizard      Fire    Flying     1.7    90.5          0
# 6      7    Squirtle     Water       NaN     0.5     9.0          0
# 7      8   Wartortle     Water       NaN     1.0    22.5          0
# 8      9   Blastoise     Water       NaN     1.6    85.5          0
# 9     10    Caterpie       Bug       NaN     0.3     2.9          0
# 10    11     Metapod       Bug       NaN     0.7     9.9          0
# 11    12  Butterfree       Bug    Flying     1.1    32.0          0
# 12    13      Weedle       Bug    Poison     0.3     3.2          0
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f485f64d-a051-4e4f-aa71-7215cd54b5c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f485f64d-a051-4e4f-aa71-7215cd54b5c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_json("output.json")

# %%
print(df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire    None     0.6     8.5          0
# 4      5  Charmeleon     Fire    None     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon    None     1.8     3.3          0
# 147  148   Dragonair   Dragon    None     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic    None     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
# Selection by column

# %%
print(df["Name"])
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 145       Moltres
# 146       Dratini
# 147     Dragonair
# 148     Dragonite
# 149        Mewtwo
# Name: Name, Length: 150, dtype: object

# %%
print(df["Name"].to_string())
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28       Nidoran♀
# 29       Nidorina
# 30      Nidoqueen
# 31       Nidoran♂
# 32       Nidorino
# 33       Nidoking
# 34       Clefairy
# 35       Clefable
# 36         Vulpix
# 37      Ninetales
# 38     Jigglypuff
# 39     Wigglytuff
# 40          Zubat
# 41         Golbat
# 42         Oddish
# 43          Gloom
# 44      Vileplume
# 45          Paras
# 46       Parasect
# 47        Venonat
# 48       Venomoth
# 49        Diglett
# ...

# %%
print(df[["Name", "Height", "Weight"]].to_string())
# Out:
#            Name  Height  Weight
# 0     Bulbasaur     0.7     6.9
# 1       Ivysaur     1.0    13.0
# 2      Venusaur     2.0   100.0
# 3    Charmander     0.6     8.5
# 4    Charmeleon     1.1    19.0
# 5     Charizard     1.7    90.5
# 6      Squirtle     0.5     9.0
# 7     Wartortle     1.0    22.5
# 8     Blastoise     1.6    85.5
# 9      Caterpie     0.3     2.9
# 10      Metapod     0.7     9.9
# 11   Butterfree     1.1    32.0
# 12       Weedle     0.3     3.2
# 13       Kakuna     0.6    10.0
# 14     Beedrill     1.0    29.5
# 15       Pidgey     0.3     1.8
# 16    Pidgeotto     1.1    30.0
# 17      Pidgeot     1.5    39.5
# 18      Rattata     0.3     3.5
# 19     Raticate     0.7    18.5
# 20      Spearow     0.3     2.0
# 21       Fearow     1.2    38.0
# 22        Ekans     2.0     6.9
# 23        Arbok     3.5    65.0
# 24      Pikachu     0.4     6.0
# 25       Raichu     0.8    30.0
# 26    Sandshrew     0.6    12.0
# 27    Sandslash     1.0    29.5
# ...

# %%
# Selection by row

# %%
print(df.loc[2])
# Out:
# No                  3
# Name         Venusaur
# Type1           Grass
# Type2          Poison
# Height            2.0
# Weight          100.0
# Legendary           0
# Name: 2, dtype: object

# %%
print(df.loc["Pikachu"])
# Out:
# No                 25
# Type1        Electric
# Type2             NaN
# Height            0.4
# Weight            6.0
# Legendary           0
# Name: Pikachu, dtype: object

# %%
print(df.loc["Snorlax", ["Height", "Weight"]])
# Out:
# Height      2.1
# Weight    460.0
# Name: Snorlax, dtype: object

# %%
print(df.loc["Snorlax":"Dratini", ["Height", "Weight"]])
# Out:
#           Height  Weight
# Name
# Snorlax      2.1   460.0
# Articuno     1.7    55.4
# Zapdos       1.6    52.6
# Moltres      2.0    60.0
# Dratini      1.8     3.3

# %%
# Selection by ROWS

# %%
print(df.iloc[:10:2,0:3])
# Out:
#             No  Type1   Type2
# Name
# Bulbasaur    1  Grass  Poison
# Venusaur     3  Grass  Poison
# Charmeleon   5   Fire     NaN
# Squirtle     7  Water     NaN
# Blastoise    9  Water     NaN

# %%
pokemon = input("Enter a pokamon name: ")
# Out:
# Enter a pokamon name: Raichu

# %%
try:
  print(df.loc[pokemon])
except KeyError:
  print("Pokemon not found")
# Out:
# No                 26
# Type1        Electric
# Type2             NaN
# Height            0.8
# Weight           30.0
# Legendary           0
# Name: Raichu, dtype: object

# %%
# Filtering Data

# %%
df = pd.read_csv("new.csv")

# %%
tall_pokemon = df[df["Height"] >= 2]

# %%
print(tall_pokemon)
# Out:
#       No        Name    Type1    Type2  Height  Weight  Legendary
# 2      3    Venusaur    Grass   Poison     2.0   100.0          0
# 22    23       Ekans   Poison      NaN     2.0     6.9          0
# 23    24       Arbok   Poison      NaN     3.5    65.0          0
# 94    95        Onix     Rock   Ground     8.8   210.0          0
# 102  103   Exeggutor    Grass  Psychic     2.0   120.0          0
# 114  115  Kangaskhan   Normal      NaN     2.2    80.0          0
# 129  130    Gyarados    Water   Flying     6.5   235.0          0
# 130  131      Lapras    Water      Ice     2.5   220.0          0
# 142  143     Snorlax   Normal      NaN     2.1   460.0          0
# 145  146     Moltres     Fire   Flying     2.0    60.0          1
# 147  148   Dragonair   Dragon      NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon   Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic      NaN     2.0   122.0          1

# %%
heavy_pokemon = df[df["Weight"] >= 90]

# %%
print(heavy_pokemon)
# Out:
#       No       Name     Type1    Type2  Height  Weight  Legendary
# 2      3   Venusaur     Grass   Poison     2.0   100.0          0
# 5      6  Charizard      Fire   Flying     1.7    90.5          0
# 58    59   Arcanine      Fire      NaN     1.9   155.0          0
# 67    68    Machamp  Fighting      NaN     1.6   130.0          0
# 74    75   Graveler      Rock   Ground     1.0   105.0          0
# 75    76      Golem      Rock   Ground     1.4   300.0          0
# 77    78   Rapidash      Fire      NaN     1.7    95.0          0
# 85    86       Seel     Water      NaN     1.1    90.0          0
# 86    87    Dewgong     Water      Ice     1.7   120.0          0
# 90    91   Cloyster     Water      Ice     1.5   132.5          0
# 94    95       Onix      Rock   Ground     8.8   210.0          0
# 102  103  Exeggutor     Grass  Psychic     2.0   120.0          0
# 110  111    Rhyhorn    Ground     Rock     1.0   115.0          0
# ...

# %%
lagend_pokemon = df[df["Legendary"] == 1]

# %%
print(lagend_pokemon)
# Out:
#       No      Name     Type1   Type2  Height  Weight  Legendary
# 143  144  Articuno       Ice  Flying     1.7    55.4          1
# 144  145    Zapdos  Electric  Flying     1.6    52.6          1
# 145  146   Moltres      Fire  Flying     2.0    60.0          1
# 149  150    Mewtwo   Psychic     NaN     2.0   122.0          1

# %%
poke_select = df[(df["Type1"] == "Grass")|
                 (df["Type2"] == "Grass")]

# %%
print(poke_select)
# Out:
#       No        Name  Type1    Type2  Height  Weight  Legendary
# 0      1   Bulbasaur  Grass   Poison     0.7     6.9          0
# 1      2     Ivysaur  Grass   Poison     1.0    13.0          0
# 2      3    Venusaur  Grass   Poison     2.0   100.0          0
# 42    43      Oddish  Grass   Poison     0.5     5.4          0
# 43    44       Gloom  Grass   Poison     0.8     8.6          0
# 44    45   Vileplume  Grass   Poison     1.2    18.6          0
# 45    46       Paras    Bug    Grass     0.3     5.4          0
# 46    47    Parasect    Bug    Grass     1.0    29.5          0
# 68    69  Bellsprout  Grass   Poison     0.7     4.0          0
# 69    70  Weepinbell  Grass   Poison     1.0     6.4          0
# 70    71  Victreebel  Grass   Poison     1.7    15.5          0
# 101  102   Exeggcute  Grass  Psychic     0.4     2.5          0
# 102  103   Exeggutor  Grass  Psychic     2.0   120.0          0
# 113  114     Tangela  Grass      NaN     1.0    35.0          0

# %%
poke1_select = df[(df["Type1"] == "Grass")&
                 (df["Type2"] == "Water")]

# %%
print(poke1_select)
# Out:
# Empty DataFrame
# Columns: [No, Name, Type1, Type2, Height, Weight, Legendary]
# Index: []

# %%
#aggregate functions. For whole dataframe

# %%
print(df.mean(numeric_only=True))
# Out:
# No           75.500000
# Height        1.200000
# Weight       46.231333
# Legendary     0.026667
# dtype: float64

# %%
print(df.sum(numeric_only=True))
# Out:
# No           11325.0
# Height         180.0
# Weight        6934.7
# Legendary        4.0
# dtype: float64

# %%
print(df.min(numeric_only=True))
# Out:
# No           1.0
# Height       0.2
# Weight       0.1
# Legendary    0.0
# dtype: float64

# %%
print(df.max(numeric_only=True))
# Out:
# No           150.0
# Height         8.8
# Weight       460.0
# Legendary      1.0
# dtype: float64

# %%
print(df.count())
# Out:
# No           150
# Name         150
# Type1        150
# Type2         67
# Height       150
# Weight       150
# Legendary    150
# dtype: int64

# %%
#aggregate function for singel column

# %%
print(df["Height"].mean())
# Out:
# 1.2

# %%
print(df["Height"].sum())
# Out:
# 180.0

# %%
print(df["Weight"].min())
# Out:
# 0.1

# %%
print(df["Weight"].max())
# Out:
# 460.0

# %%
print(df["Weight"].count())
# Out:
# 150

# %%
group = df.groupby("Type1")

# %%
print(group)

# %%
print(group["Height"].mean())
# Out:
# Type1
# Bug         0.900000
# Dragon      2.666667
# Electric    0.855556
# Fairy       0.950000
# Fighting    1.185714
# Fire        1.216667
# Ghost       1.466667
# Grass       1.083333
# Ground      0.850000
# Ice         1.550000
# Normal      0.986364
# Poison      1.221429
# Psychic     1.371429
# Rock        1.844444
# Water       1.300000
# Name: Height, dtype: float64

# %%
print(group["Height"].min())
# Out:
# Type1
# Bug         0.3
# Dragon      1.8
# Electric    0.3
# Fairy       0.6
# Fighting    0.5
# Fire        0.6
# Ghost       1.3
# Grass       0.4
# Ground      0.2
# Ice         1.4
# Normal      0.3
# Poison      0.4
# Psychic     0.9
# Rock        0.4
# Water       0.3
# Name: Height, dtype: float64

# %%
# DATA CLEANING

# %%
new_df = df.drop(columns=["Legendary"])

# %%
print(new_df)
# Out:
#       No        Name    Type1   Type2  Height  Weight
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9
# 1      2     Ivysaur    Grass  Poison     1.0    13.0
# 2      3    Venusaur    Grass  Poison     2.0   100.0
# 3      4  Charmander     Fire     NaN     0.6     8.5
# 4      5  Charmeleon     Fire     NaN     1.1    19.0
# ..   ...         ...      ...     ...     ...     ...
# 145  146     Moltres     Fire  Flying     2.0    60.0
# 146  147     Dratini   Dragon     NaN     1.8     3.3
# 147  148   Dragonair   Dragon     NaN     4.0    16.5
# 148  149   Dragonite   Dragon  Flying     2.2   210.0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0
#
# [150 rows x 6 columns]

# %%
new_df = df.drop(columns=["Type2", "No"])

# %%
print(new_df)
# Out:
#            Name    Type1  Height  Weight  Legendary
# 0     Bulbasaur    Grass     0.7     6.9          0
# 1       Ivysaur    Grass     1.0    13.0          0
# 2      Venusaur    Grass     2.0   100.0          0
# 3    Charmander     Fire     0.6     8.5          0
# 4    Charmeleon     Fire     1.1    19.0          0
# ..          ...      ...     ...     ...        ...
# 145     Moltres     Fire     2.0    60.0          1
# 146     Dratini   Dragon     1.8     3.3          0
# 147   Dragonair   Dragon     4.0    16.5          0
# 148   Dragonite   Dragon     2.2   210.0          0
# 149      Mewtwo  Psychic     2.0   122.0          1
#
# [150 rows x 5 columns]

# %%
new_df = df.dropna(subset=["Type2"])

# %%
print(new_df)
# Out:
#       No        Name     Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur     Grass  Poison     1.0    13.0          0
# 2      3    Venusaur     Grass  Poison     2.0   100.0          0
# 5      6   Charizard      Fire  Flying     1.7    90.5          0
# 11    12  Butterfree       Bug  Flying     1.1    32.0          0
# ..   ...         ...       ...     ...     ...     ...        ...
# 141  142  Aerodactyl      Rock  Flying     1.8    59.0          0
# 143  144    Articuno       Ice  Flying     1.7    55.4          1
# 144  145      Zapdos  Electric  Flying     1.6    52.6          1
# 145  146     Moltres      Fire  Flying     2.0    60.0          1
# 148  149   Dragonite    Dragon  Flying     2.2   210.0          0
#
# [67 rows x 7 columns]

# %%
print(new_df.to_string())
# Out:
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass    Poison     0.7     6.9          0
# 1      2     Ivysaur     Grass    Poison     1.0    13.0          0
# 2      3    Venusaur     Grass    Poison     2.0   100.0          0
# 5      6   Charizard      Fire    Flying     1.7    90.5          0
# 11    12  Butterfree       Bug    Flying     1.1    32.0          0
# 12    13      Weedle       Bug    Poison     0.3     3.2          0
# 13    14      Kakuna       Bug    Poison     0.6    10.0          0
# 14    15    Beedrill       Bug    Poison     1.0    29.5          0
# 15    16      Pidgey    Normal    Flying     0.3     1.8          0
# 16    17   Pidgeotto    Normal    Flying     1.1    30.0          0
# 17    18     Pidgeot    Normal    Flying     1.5    39.5          0
# 20    21     Spearow    Normal    Flying     0.3     2.0          0
# 21    22      Fearow    Normal    Flying     1.2    38.0          0
# ...

# %%
new_df = df.fillna({"Type2":"None"})

# %%
print(new_df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire    None     0.6     8.5          0
# 4      5  Charmeleon     Fire    None     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon    None     1.8     3.3          0
# 147  148   Dragonair   Dragon    None     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic    None     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
new_df["Type1"] = new_df["Type1"].replace({"Grass":"Herbivorous", "Fire":" Firefly"})

# %%
print(new_df)
# Out:
#       No        Name        Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur  Herbivorous  Poison     0.7     6.9          0
# 1      2     Ivysaur  Herbivorous  Poison     1.0    13.0          0
# 2      3    Venusaur  Herbivorous  Poison     2.0   100.0          0
# 3      4  Charmander      Firefly    None     0.6     8.5          0
# 4      5  Charmeleon      Firefly    None     1.1    19.0          0
# ..   ...         ...          ...     ...     ...     ...        ...
# 145  146     Moltres      Firefly  Flying     2.0    60.0          1
# 146  147     Dratini       Dragon    None     1.8     3.3          0
# 147  148   Dragonair       Dragon    None     4.0    16.5          0
# 148  149   Dragonite       Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo      Psychic    None     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
# Standardise text

# %%
new_df["Name"] = new_df["Name"].str.lower()

# %%
print(new_df)
# Out:
#       No        Name        Type1   Type2  Height  Weight  Legendary
# 0      1   bulbasaur  Herbivorous  Poison     0.7     6.9          0
# 1      2     ivysaur  Herbivorous  Poison     1.0    13.0          0
# 2      3    venusaur  Herbivorous  Poison     2.0   100.0          0
# 3      4  charmander      Firefly    None     0.6     8.5          0
# 4      5  charmeleon      Firefly    None     1.1    19.0          0
# ..   ...         ...          ...     ...     ...     ...        ...
# 145  146     moltres      Firefly  Flying     2.0    60.0          1
# 146  147     dratini       Dragon    None     1.8     3.3          0
# 147  148   dragonair       Dragon    None     4.0    16.5          0
# 148  149   dragonite       Dragon  Flying     2.2   210.0          0
# 149  150      mewtwo      Psychic    None     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
 # Fix Data Type

# %%
new_df["Legendary"] = new_df["Legendary"].astype(bool)

# %%
print(new_df)
# Out:
#       No        Name        Type1   Type2  Height  Weight  Legendary
# 0      1   bulbasaur  Herbivorous  Poison     0.7     6.9      False
# 1      2     ivysaur  Herbivorous  Poison     1.0    13.0      False
# 2      3    venusaur  Herbivorous  Poison     2.0   100.0      False
# 3      4  charmander      Firefly    None     0.6     8.5      False
# 4      5  charmeleon      Firefly    None     1.1    19.0      False
# ..   ...         ...          ...     ...     ...     ...        ...
# 145  146     moltres      Firefly  Flying     2.0    60.0       True
# 146  147     dratini       Dragon    None     1.8     3.3      False
# 147  148   dragonair       Dragon    None     4.0    16.5      False
# 148  149   dragonite       Dragon  Flying     2.2   210.0      False
# 149  150      mewtwo      Psychic    None     2.0   122.0       True
#
# [150 rows x 7 columns]

# %%
# Remove Duplicate

# %%
new_df = df.drop_duplicates()
